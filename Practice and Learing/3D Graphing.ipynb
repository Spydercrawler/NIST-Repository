# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_vals = np.linspace(0,10,50)
sin_vals = np.sin(x_vals)
x_vals,sin_vals = np.meshgrid(x_vals,sin_vals)
random_vals = [np.linspace(10,0,50).tolist()] * 50
print random_vals[0]
# Out:
# [10.0, 9.795918367346939, 9.591836734693878, 9.387755102040817, 9.183673469387756, 8.979591836734693, 8.775510204081632, 8.571428571428571, 8.36734693877551, 8.16326530612245, 7.959183673469388, 7.755102040816326, 7.551020408163265, 7.346938775510204, 7.142857142857142, 6.938775510204081, 6.73469387755102, 6.530612244897959, 6.326530612244898, 6.122448979591836, 5.918367346938775, 5.714285714285714, 5.5102040816326525, 5.3061224489795915, 5.1020408163265305, 4.8979591836734695, 4.6938775510204085, 4.489795918367347, 4.285714285714286, 4.081632653061225, 3.8775510204081627, 3.6734693877551017, 3.4693877551020407, 3.2653061224489797, 3.0612244897959187, 2.8571428571428568, 2.6530612244897958, 2.4489795918367347, 2.244897959183673, 2.040816326530612, 1.8367346938775508, 1.6326530612244898, 1.4285714285714288, 1.2244897959183678, 1.020408163265305, 0.816326530612244, 0.612244897959183, 0.408163265306122, 0.204081632653061, 0.0]

# %%
plt.ion()
surf = ax.plot_surface(x_vals,sin_vals,random_vals, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.draw()
